# %% [markdown]
# # Q1. What is the mathematical formula for a linear SVM?

# %% [markdown]
# # ANS
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Q2. What is the objective function of a linear SVM?

# %% [markdown]
# # ANS:-

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-03-10 171657.png](data:image/png;base64,...)

# %% [markdown]
# # Q3. What is the kernel trick in SVM?

# %% [markdown]
# # ANS:
#
# The kernel trick is a technique used in Support Vector Machines (SVMs) to implicitly transform the input features into a higher-dimensional space without explicitly computing the transformation. This is achieved by using a kernel function, which calculates the dot product between the transformed feature vectors in the higher-dimensional space without explicitly representing those vectors. The kernel trick allows SVMs to efficiently handle non-linear relationships between features.
#
# The standard linear SVM decision function is given by:

# %% [markdown]
# ![Screenshot 2024-03-10 171858.png](data:image/png;base64,...)

# %% [markdown]
# # Q4. What is the role of support vectors in SVM Explain with example

# %% [markdown]
# # ANS:
#
#
# Support vectors play a crucial role in Support Vector Machines (SVMs). In SVM, the algorithm aims to find the optimal hyperplane that separates different classes in the feature space. Support vectors are the data points that are most important for defining this optimal hyperplane. They are the points that either lie on the margins or are misclassified, influencing the position and orientation of the decision boundary.
