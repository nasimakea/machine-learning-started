# %% [markdown]
# # Q1. What is Min-Max scaling, and how is it used in data preprocessing? Provide an example to illustrate its application.

# %% [markdown]
# # ANS:- The min max scaling is the process in which the given data is processed in the comparable range of [0,1] with the one of the normalization technique which is also known as min_max_scaler or feature scaling. let's understand with the help of an example

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=sns.load_dataset('taxis')
df.columns
# Out:
# Index(['pickup', 'dropoff', 'passengers', 'distance', 'fare', 'tip', 'tolls',
#        'total', 'color', 'payment', 'pickup_zone', 'dropoff_zone',
#        'pickup_borough', 'dropoff_borough'],
#       dtype='object')

# %%
df.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
min_max=MinMaxScaler()

# %%
min_max
# Out:
# MinMaxScaler()

# %%
min_max.fit_transform(df[['distance', 'fare', 'tip', 'tolls',
       'total']])
# Out:
# array([[0.04359673, 0.04026846, 0.06475904, 0.        , 0.06713923],
#        [0.02152589, 0.02684564, 0.        , 0.        , 0.0461042 ],
#        [0.0373297 , 0.04362416, 0.07108434, 0.        , 0.07411249],
#        ...,
#        [0.11280654, 0.10067114, 0.        , 0.        , 0.09220839],
#        [0.03051771, 0.03355705, 0.        , 0.        , 0.03169663],
#        [0.10490463, 0.09395973, 0.10120482, 0.        , 0.10869064]])

# %%
df2=pd.DataFrame(min_max.fit_transform(df[['distance', 'fare', 'tip', 'tolls',
       'total']]),columns=['distance', 'fare', 'tip', 'tolls',
       'total'])

# %%
df2.head()
# Out:
#    distance      fare       tip  tolls     total
# 0  0.043597  0.040268  0.064759    0.0  0.067139
# 1  0.021526  0.026846  0.000000    0.0  0.046104
# 2  0.037330  0.043624  0.071084    0.0  0.074112
# 3  0.209809  0.174497  0.185241    0.0  0.205452
# 4  0.058856  0.053691  0.033133    0.0  0.069733

# %%
sns.scatterplot(x=df['distance'],y=df['fare'])
# Out:
# <Axes: xlabel='distance', ylabel='fare'>

# %%
sns.scatterplot(x=df2['distance'],y=df2['fare'])
# Out:
# <Axes: xlabel='distance', ylabel='fare'>

# %% [markdown]
# # Q2. What is the Unit Vector technique in feature scaling, and how does it differ from Min-Max scaling? Provide an example to illustrate its application.

# %% [markdown]
# # ANS:
# #The basic differnence between the unit vector and min max scaling is just that in case of unit vector, the data points are divivided by their magnitude , they are said to have 1 value and direction but talking about min max scaling , the data points are normalize , and have the value in the range of [0,1]. let's understand with the helpof example

# %%
df=sns.load_dataset('taxis')

# %%
df.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# ...

# %%
from sklearn.preprocessing import normalize

# %%
df.columns
# Out:
# Index(['pickup', 'dropoff', 'passengers', 'distance', 'fare', 'tip', 'tolls',
#        'total', 'color', 'payment', 'pickup_zone', 'dropoff_zone',
#        'pickup_borough', 'dropoff_borough'],
#       dtype='object')

# %%
normalize(df[['distance', 'fare', 'tip', 'tolls',
       'total']])
# Out:
# array([[0.10693195, 0.46782728, 0.14368981, 0.        , 0.86548046],
#        [0.07460999, 0.47221512, 0.        , 0.        , 0.87832012],
#        [0.08428542, 0.46141651, 0.1451924 , 0.        , 0.87115437],
#        ...,
#        [0.17303713, 0.66874253, 0.        , 0.        , 0.72307786],
#        [0.12257146, 0.65663281, 0.        , 0.        , 0.74418385],
#        [0.15014138, 0.58496641, 0.13103248, 0.        , 0.78619486]])

# %%
import pandas as pd
df1=pd.DataFrame(normalize(df[['distance', 'fare', 'tip', 'tolls',
       'total']]),columns=['distance', 'fare', 'tip', 'tolls',
       'total'])

# %%
df1.head()
# Out:
#    distance      fare       tip  tolls     total
# 0  0.106932  0.467827  0.143690    0.0  0.865480
# 1  0.074610  0.472215  0.000000    0.0  0.878320
# 2  0.084285  0.461417  0.145192    0.0  0.871154
# 3  0.164486  0.576768  0.131375    0.0  0.789318
# 4  0.132330  0.551374  0.067390    0.0  0.820935

# %% [markdown]
# # now let us see the min max scaler

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
min_max=MinMaxScaler()

# %%
df2=pd.DataFrame(min_max.fit_transform(df[['distance', 'fare', 'tip', 'tolls',
       'total']]),columns=['distance', 'fare', 'tip', 'tolls',
       'total'])

# %%
df2.head()
# Out:
#    distance      fare       tip  tolls     total
# 0  0.043597  0.040268  0.064759    0.0  0.067139
# 1  0.021526  0.026846  0.000000    0.0  0.046104
# 2  0.037330  0.043624  0.071084    0.0  0.074112
# 3  0.209809  0.174497  0.185241    0.0  0.205452
# 4  0.058856  0.053691  0.033133    0.0  0.069733

# %% [markdown]
# # Q3. What is PCA (Principle Component Analysis), and how is it used in dimensionality reduction? Provide an example to illustrate its application.

# %% [markdown]
# # ANS:-
# #Principal Component Analysis (PCA) is a dimensionality reduction technique commonly used in machine learning and statistics. Its primary goal is to transform a high-dimensional dataset into a lower-dimensional space while retaining as much of the original variance as possible. This reduction in dimensionality helps simplify the data, making it easier to analyze and visualize while preserving the essential information.

# %%
import numpy as np
from sklearn.decomposition import PCA
from sklearn.datasets import load_iris

# Load the Iris dataset
iris = load_iris()
X = iris.data
y = iris.target

# Standardize the data
X_standardized = (X - np.mean(X, axis=0)) / np.std(X, axis=0)

# Apply PCA with 2 components
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_standardized)

# Display the variance explained by each principal component
print("Explained Variance Ratio:", pca.explained_variance_ratio_)

# Plot the data in the reduced-dimensional space
import matplotlib.pyplot as plt

plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap='viridis')
plt.title('PCA of Iris Dataset')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()
# Out:
# Explained Variance Ratio: [0.72962445 0.22850762]

# %% [markdown]
# # Q4. What is the relationship between PCA and Feature Extraction, and how can PCA be used for Feature Extraction? Provide an example to illustrate this concept.

# %% [markdown]
# # ANS:-
#
# #PCA (Principal Component Analysis) is often used as a technique for feature extraction in machine learning. Feature extraction refers to the process of transforming the original features of a dataset into a new set of features that capture the most relevant information while reducing dimensionality. PCA achieves this by identifying and retaining the principal components that explain the maximum variance in the data.
#
# #The relationship between PCA and feature extraction lies in the fact that the principal components obtained through PCA can be considered as new features, and they are linear combinations of the original features. These principal components are ordered by the amount of variance they explain, making it possible to select a subset of them to represent the data in a lower-dimensional space.

# %% [markdown]
# # Q5. You are working on a project to build a recommendation system for a food delivery service. The dataset contains features such as price, rating, and delivery time. Explain how you would use Min-Max scaling to preprocess the data.

# %%
#

# %% [markdown]
# # ANS:-
# #Min-Max scaling is a data normalization technique used to scale numerical features within a specific range, typically between 0 and 1. This process is particularly useful when dealing with features that have different scales, as it ensures that all features contribute equally to the model.

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
import pandas as pd

# %%
df2=pd.read_csv("/content/archive (8).zip")

# %%
df2
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 0     20  Female         Single    Student       No Income
# 1     24  Female         Single    Student  Below Rs.10000
# 2     22    Male         Single    Student  Below Rs.10000
# 3     22  Female         Single    Student       No Income
# 4     22    Male         Single    Student  Below Rs.10000
# ..   ...     ...            ...        ...             ...
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate            4   12.9766    77.5993    560001
# 1                     Graduate            3   12.9770    77.5773    560009
# ...

# %%
df2.columns
# Out:
# Index(['Age', 'Gender', 'Marital Status', 'Occupation', 'Monthly Income',
#        'Educational Qualifications', 'Family size', 'latitude', 'longitude',
#        'Pin code', 'Medium (P1)', 'Medium (P2)', 'Meal(P1)', 'Meal(P2)',
#        'Perference(P1)', 'Perference(P2)', 'Ease and convenient',
#        'Time saving', 'More restaurant choices', 'Easy Payment option',
#        'More Offers and Discount', 'Good Food quality', 'Good Tracking system',
#        'Self Cooking', 'Health Concern', 'Late Delivery', 'Poor Hygiene',
#        'Bad past experience', 'Unavailability', 'Unaffordable',
#        'Long delivery time', 'Delay of delivery person getting assigned',
#        'Delay of delivery person picking up food', 'Wrong order delivered',
#        'Missing item', 'Order placed by mistake', 'Influence of time',
#        'Order Time', 'Maximum wait time', 'Residence in busy location',
#        'Google Maps Accuracy', 'Good Road Condition', 'Low quantity low time',
# ...

# %%
# Out:
# 0             Neutral
# 1      Strongly agree
# 2             Neutral
# 3               Agree
# 4               Agree
#             ...
# 383             Agree
# 384           Neutral
# 385             Agree
# 386    Strongly agree
# 387             Agree
# Name: Easy Payment option, Length: 388, dtype: object

# %% [markdown]
# # Q6. You are working on a project to build a model to predict stock prices. The dataset contains many features, such as company financial data and market trends. Explain how you would use PCA to reduce the dimensionality of the dataset.
